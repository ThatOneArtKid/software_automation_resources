# %% [markdown]
# # Week 2 - Problem Set
#
# Practice what you learnt today with these problems; I will share the answers on Monday before the next workshop.

# %%
# Run the dependencies before you begin
import numpy as np
import matplotlib.pyplot as plt
from utils_common import generate_data

plt.style.use('ggplot')

# %% [markdown]
# **1. Using MD syntax, create a table of the two regression algorithms we have covered so far with the following headings.**
#
# - Algorithm
# - Regression or Classification
# - Popular uses

# %% [markdown]
# | Algorithm | Regression/classification | Popular uses |
# | ----------- | ----------- | ----------- |
# | Linear | Regression | Predicting something based on certain variables |
# | Logistic | Classification | Classifying something into a certain category |

# %% [markdown]
# **2. In a markdown block, outline why more than 3 degrees of polynomial expression are not recommended in Machine Learning.**

# %% [markdown]
# It is not recommended to use more than 3 degrees of polynomial expression in machine learning, as this can make the machine prone to overfitting data, which can cause issues when predicting new data, and can amplify outliers.

# %% [markdown]
# **3. Modify the code block below to label the two categories, apply a colour to each category, enable the legend, add a title "Logistic Data," and label the X & Y Axis with "Feature" and "Target."**
#
# | Category | Label |
# | --- | --- |
# | 0 | Australia |
# | 1 | New Zealand |

# %%
# Linear Regression For Classification
m = generate_data(20, 50, 0, 0, 300, 0.8)
n = generate_data(0, 30, 1, 1, 300, 0.8)
plt.scatter(m[0], m[1], c='r')
plt.scatter(n[0], n[1], c='r')
plt.title("Logistic Data")
plt.ylabel("Target")
plt.xlabel("Feature")
plt.legend()
plt.colorbar()
plt.show()
# Out:
# /tmp/ipykernel_1755/2200219639.py:9: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# **4. In a markdown block, outline why Linear Regression is not a good machine learning model for classification.**

# %% [markdown]
# Linear regression is not a good machine learning model for classification, as it sorts data based on a straight line - which causes a few issues, however the biggest problem is that this function does not work well when classifying boundary values (values which lie close enough to both classes that a linear regression algorithm is significantly more likely to classify them incorrectly).

# %% [markdown]
# __5. In a markdown block, outline the machine learning Logistic Regression algorithm.__

# %% [markdown]
# Logistic regression is a machine learning algorithm used for categorising data. The algorithm takes data inputs and sorts them into one of two classes using a sigmoid function, which makes it easier to classify boundary values.

# %% [markdown]
# **6. Using the [OOP Logistic Regression](4.OOP_Logistic_Regression.ipynb) as an example, design, fit and evaluate an [Iris classification OOP implementation](6.OOP_Iris_Logistic_Regression.ipynb).**

# %% [markdown]
# __7. After completing Logistic Regression for the Iris data set (Q6), justify why you selected the features you did for your model.__

# %% [markdown]
# For the model I created in question 6, I used logistic regression for the reasons mentioned above, in order to create more accurate predictions - proven to be true when looking at the model's evaluation, with very little MAE and MSE.
